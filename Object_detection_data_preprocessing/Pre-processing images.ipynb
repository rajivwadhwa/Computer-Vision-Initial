# %%
import os
import pandas as pd
import numpy as np
import scipy
import math
import cv2
from google.colab import drive
import seaborn as sns

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
data_dir = os.path.abspath('/content/gdrive/My Drive/YOLO_dataset/TrainIJCNN2013_annotated')
os.path.exists(data_dir)
# Out:
# True

# %%
def resize_cv(img):
    return cv2.resize(img, (64, 64), interpolation = cv2.INTER_AREA)

def grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

list_images = []
outputclass = []

for dir in os.listdir(data_dir):
    
    inner_dir = os.path.join(data_dir, dir)
    csv_file = pd.read_csv(os.path.join(inner_dir,"gt" + dir + '.csv'), sep=';')
    for row in csv_file.iterrows() :
        img_path = os.path.join(inner_dir, row[1].Filename)
        img = imread(img_path)
        img = img[row[1]['Roi.X1']:row[1]['Roi.X2'],row[1]['Roi.Y1']:row[1]['Roi.Y2'],:]
        img = resize_cv(img)
        img = grayscale(img)

        list_images.append(img)
        outputclass.append(row[1].ClassId)


#Plotting the uneven images in the dataset 
fig = sns.distplot(output, kde=False, bins = 43, hist = True, hist_kws=dict(edgecolor="black", linewidth=2))
fig.set(title = "Traffic signs Distribution", xlabel = "ClassId", ylabel = "Frequency")

input_array = np.stack(list_images)
    
#We get the list_images to give for learning algorithm, along with labels.
